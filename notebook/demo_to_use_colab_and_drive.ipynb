# %% [markdown]
# # Demo to use colab-gpu directly on remote (shared) drive with cloned repo

# %% [markdown]
# Inside the notebook to run, mount google drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# then change directory and run setup.sh to log your username

# %%
# %cd /content/drive/MyDrive/statistical-qst-vae/statistical-qst-vae/
# Out:
# /content/drive/.shortcut-targets-by-id/1z6SyfaV05V37GIw6sCylZSGL9vSkebul/statistical-qst-vae/statistical-qst-vae

# %%
# !bash setup.sh

# %% [markdown]
# You can either run shortcuts in the colab terminal to perform usefull commands

# %% [markdown]
# Shortcut git disponibili:
#   * gs         → git status
#   * gpl        → git pull
#   * gps        → git push
#   * gc 'msg'   → git add -A + commit
#   * gcps 'msg' → commit + push in un colpo
#   * glog       → ultimi 10 commit

# %% [markdown]
# remember to commit and pull your results before closing the session

# %% [markdown]
# You can directly paste the next cells into your notebooks

# %% [markdown]
# # colab-setup

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/statistical-qst-vae/statistical-qst-vae/
# !bash setup.sh
