# %% [markdown]
# Grafico / esempio di vantaggio vae: probabilmente su 4 qubit
#
# finestra di sample in cui:
#
# fidelity train è piu bassa di fidelity ricostruita, grafico deltadist train vs vae gen (quello rifatto n volte)

# %% [markdown]
# studio di "scalabilità"? fidelity vs N vs N qubit (fino a 8-10(?)), anche solo singola run

# %% [markdown]
# # Import

# %%
# general import: 
import sys
import time
import os
import gc
from pathlib import Path
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# quantum import:
from qiskit import QuantumCircuit
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_state_city, plot_state_hinton, plot_state_qsphere

# %%
# ML import:
import tensorflow as tf
import keras
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import sklearn
from sklearn.model_selection import train_test_split

# %%
# custom helper and libraries:
sys.path.append('../src')
from povm_sampling import *
from statesprep import *
from vae import *
from plots import *
from utils import *
from mle import *

# %%
PROJECT_ROOT = Path("/Users/riccardoruggeri/project-sda/statistical-qst-vae")
RESULTS_ROOT = PROJECT_ROOT / "results/scalability_vae_analysis"

# %%
N_SAMPLES = [300, 500, 1000, 2000, 5000, 10000]
N_QUBITS = 4

# geometria (latent_dim, hidden, N_GEN) per numero di qubit
CFG = {
    #3: dict(latent_dim=16,  hidden=96,  batch_size=100, N_GEN=20000),
    4: dict(latent_dim=32,  hidden=128,  batch_size=200, N_GEN=100000),
    #5: dict(latent_dim=64,  hidden=224,  batch_size=500, N_GEN=4**5 * 500),
    #6: dict(latent_dim=256, hidden=1280, batch_size=600, N_GEN=4**6 * 500),
    #7: dict(latent_dim=512, hidden=1504, batch_size=800, N_GEN=4**7 * 500),
    #8: dict(latent_dim=512, hidden=2560, batch_size=1000, N_GEN=4**8 * 500),
}

for i in range(20):
    # accumulo i risultati per il plot finale: una curva per ogni numero di qubit
    results = {"n_samples": [], "Fc": [], "Fc_train": []}

    # GHZ esatto + distribuzione POVM vera
    qc = create_ghz_state(N_QUBITS)
    rho = DensityMatrix(qc)
    P_exact = povm_probability_efficient(rho.data, N_QUBITS)
    outcomes = list(P_exact.keys())            # ricalcolato per ogni q (era un bug: restava a 3 qubit)

    for n in N_SAMPLES:
        print(f"\n=== N_QUBITS={N_QUBITS}   N_SAMPLES={n} ===")
        n_samples = n
        
        seed = np.random.seed()
        # campiona la distribuzione e prepara i dati
        sample = sample_povm(P_exact, n_samples=n_samples, seed=seed)
        onehot_sample = samples_to_onehot(sample, N_QUBITS)
        X_train, X_test = train_test_split(onehot_sample, test_size=0.2, random_state=42)

        cfg = CFG[N_QUBITS]
        latent_dim, hidden, batch_size, N_GEN = cfg["latent_dim"], cfg["hidden"], cfg["batch_size"], cfg["N_GEN"]

        vae = VAE(n_qubits=N_QUBITS, latent_dim=latent_dim, hidden=hidden)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3))
        vae.build(input_shape=(None, 4 * N_QUBITS))  # input_shape=(None, 4 * n_qubits) per one-hot encoding
        model = vae

        WARMUP = 40   # epoche di warm-up della KL (0 -> beta_max)
        callbacks = [
            KLWarmup(beta_max=0.85, warmup_epochs=WARMUP),
            EarlyStopping(monitor='reconstruction_loss', mode='min',
                            patience=40, restore_best_weights=True, start_from_epoch=WARMUP),
        ]

        history = model.fit(
            X_train, X_train,
            epochs=500,
            batch_size=batch_size,
            validation_data=(X_test, X_test),
            callbacks=callbacks,
            verbose=0,
        )

        # save results
        drive_path = RESULTS_ROOT / "run_{}".format(i+1)
        run_dir, checkpoint_path, history_path = set_up_training(experiment_id='vae_training_q{}_n{}'.format(N_QUBITS, n), drive_path = drive_path)
        model.save_weights(checkpoint_path)
        pd.DataFrame(history.history).to_csv(history_path, index=False)

        # campiona dal VAE e calcola le metriche vs la distribuzione esatta
        P_vae   = vae.predict_dist(n_samples=N_GEN, batch_size=50_000)
        P_train = samples_to_empirical_dist(onehot_to_samples(X_train, N_QUBITS), N_QUBITS)

        Fc        = classical_fidelity(P_vae,   P_exact)
        Fc_train  = classical_fidelity(P_train, P_exact)

        # Print with minimal informations
        print(f"  Fidelity classica VAE vs esatta : {Fc:.4f}   <- MODELLO")
        print(f"  Fidelity classica training vs esatta : {Fc_train:.4f}   <- TETTO")

        # salvo la fidelity classica per il plot al variare di N_SAMPLES e N_QUBITS
        # (atteso: cresce con n_samples, cala con n_qubits)
        results["n_samples"].append(n)
        results["Fc"].append(Fc)
        results["Fc_train"].append(Fc_train)

    print("\nRESULTS:", results)

    results_df = pd.DataFrame(results)

    # Save the results to a CSV file for later analysis and plotting PROJECT_ROOT
    results_df.to_csv(drive_path / "4q_vae_advantage.csv", index=False)
# Out:
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_1/vae_training_q4_n300_0616_1129
#   Fidelity classica VAE vs esatta : 0.9562   <- MODELLO
#   Fidelity classica training vs esatta : 0.8371   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_1/vae_training_q4_n500_0616_1129
#   Fidelity classica VAE vs esatta : 0.9715   <- MODELLO
#   Fidelity classica training vs esatta : 0.8854   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_1/vae_training_q4_n1000_0616_1129
#   Fidelity classica VAE vs esatta : 0.9653   <- MODELLO
#   Fidelity classica training vs esatta : 0.9487   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_1/vae_training_q4_n2000_0616_1129
#   Fidelity classica VAE vs esatta : 0.9668   <- MODELLO
#   Fidelity classica training vs esatta : 0.9778   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_1/vae_training_q4_n5000_0616_1130
#   Fidelity classica VAE vs esatta : 0.9745   <- MODELLO
#   Fidelity classica training vs esatta : 0.9916   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_1/vae_training_q4_n10000_0616_1130
#   Fidelity classica VAE vs esatta : 0.9895   <- MODELLO
#   Fidelity classica training vs esatta : 0.9956   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9562061169686977), np.float64(0.9715187431096551), np.float64(0.9653244269710876), np.float64(0.9667560919321903), np.float64(0.9744738437864993), np.float64(0.9895263206041789)], 'Fc_train': [np.float64(0.8370759895474099), np.float64(0.8853850796467194), np.float64(0.94868056984058), np.float64(0.9777763125227324), np.float64(0.9916314089608144), np.float64(0.9955532053090967)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_2/vae_training_q4_n300_0616_1130
#   Fidelity classica VAE vs esatta : 0.9472   <- MODELLO
#   Fidelity classica training vs esatta : 0.7823   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_2/vae_training_q4_n500_0616_1130
#   Fidelity classica VAE vs esatta : 0.9545   <- MODELLO
#   Fidelity classica training vs esatta : 0.8759   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_2/vae_training_q4_n1000_0616_1130
#   Fidelity classica VAE vs esatta : 0.9611   <- MODELLO
#   Fidelity classica training vs esatta : 0.9507   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_2/vae_training_q4_n2000_0616_1130
#   Fidelity classica VAE vs esatta : 0.9721   <- MODELLO
#   Fidelity classica training vs esatta : 0.9707   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_2/vae_training_q4_n5000_0616_1131
#   Fidelity classica VAE vs esatta : 0.9861   <- MODELLO
#   Fidelity classica training vs esatta : 0.9916   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_2/vae_training_q4_n10000_0616_1131
#   Fidelity classica VAE vs esatta : 0.9899   <- MODELLO
#   Fidelity classica training vs esatta : 0.9964   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9472498939736392), np.float64(0.9545254574963774), np.float64(0.9610765073662356), np.float64(0.9720793687400461), np.float64(0.9860695998832326), np.float64(0.989907983747258)], 'Fc_train': [np.float64(0.7823051585715015), np.float64(0.8759136923013695), np.float64(0.9506598170261044), np.float64(0.970725749581946), np.float64(0.9915641311238977), np.float64(0.9963711090329557)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_3/vae_training_q4_n300_0616_1131
#   Fidelity classica VAE vs esatta : 0.9522   <- MODELLO
#   Fidelity classica training vs esatta : 0.8137   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_3/vae_training_q4_n500_0616_1132
#   Fidelity classica VAE vs esatta : 0.9546   <- MODELLO
#   Fidelity classica training vs esatta : 0.8854   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_3/vae_training_q4_n1000_0616_1132
#   Fidelity classica VAE vs esatta : 0.9655   <- MODELLO
#   Fidelity classica training vs esatta : 0.9501   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_3/vae_training_q4_n2000_0616_1132
#   Fidelity classica VAE vs esatta : 0.9792   <- MODELLO
#   Fidelity classica training vs esatta : 0.9736   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_3/vae_training_q4_n5000_0616_1132
#   Fidelity classica VAE vs esatta : 0.9835   <- MODELLO
#   Fidelity classica training vs esatta : 0.9923   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_3/vae_training_q4_n10000_0616_1132
#   Fidelity classica VAE vs esatta : 0.9864   <- MODELLO
#   Fidelity classica training vs esatta : 0.9955   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9522433546617963), np.float64(0.9545916036241763), np.float64(0.9654605184864113), np.float64(0.9792383798757024), np.float64(0.9835269349755328), np.float64(0.9863561781685884)], 'Fc_train': [np.float64(0.8136641898962215), np.float64(0.8854081657350297), np.float64(0.9501069199646968), np.float64(0.9736020072752665), np.float64(0.9922949272321668), np.float64(0.9955397535829311)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_4/vae_training_q4_n300_0616_1132
#   Fidelity classica VAE vs esatta : 0.9552   <- MODELLO
#   Fidelity classica training vs esatta : 0.8133   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_4/vae_training_q4_n500_0616_1132
#   Fidelity classica VAE vs esatta : 0.9567   <- MODELLO
#   Fidelity classica training vs esatta : 0.8930   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_4/vae_training_q4_n1000_0616_1132
#   Fidelity classica VAE vs esatta : 0.9626   <- MODELLO
#   Fidelity classica training vs esatta : 0.9409   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_4/vae_training_q4_n2000_0616_1132
#   Fidelity classica VAE vs esatta : 0.9764   <- MODELLO
#   Fidelity classica training vs esatta : 0.9729   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_4/vae_training_q4_n5000_0616_1133
#   Fidelity classica VAE vs esatta : 0.9860   <- MODELLO
#   Fidelity classica training vs esatta : 0.9904   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_4/vae_training_q4_n10000_0616_1133
#   Fidelity classica VAE vs esatta : 0.9896   <- MODELLO
#   Fidelity classica training vs esatta : 0.9963   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9552173479757825), np.float64(0.9566575435200438), np.float64(0.9625786305608852), np.float64(0.9763623104421101), np.float64(0.9860384789815178), np.float64(0.989610530152482)], 'Fc_train': [np.float64(0.813266889646962), np.float64(0.8929710621778001), np.float64(0.9408732819654012), np.float64(0.9728522236690149), np.float64(0.9903848570402014), np.float64(0.9963126472993837)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_5/vae_training_q4_n300_0616_1133
#   Fidelity classica VAE vs esatta : 0.9643   <- MODELLO
#   Fidelity classica training vs esatta : 0.8067   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_5/vae_training_q4_n500_0616_1133
#   Fidelity classica VAE vs esatta : 0.9514   <- MODELLO
#   Fidelity classica training vs esatta : 0.8610   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_5/vae_training_q4_n1000_0616_1133
#   Fidelity classica VAE vs esatta : 0.9679   <- MODELLO
#   Fidelity classica training vs esatta : 0.9402   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_5/vae_training_q4_n2000_0616_1133
#   Fidelity classica VAE vs esatta : 0.9768   <- MODELLO
#   Fidelity classica training vs esatta : 0.9741   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_5/vae_training_q4_n5000_0616_1134
#   Fidelity classica VAE vs esatta : 0.9851   <- MODELLO
#   Fidelity classica training vs esatta : 0.9917   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_5/vae_training_q4_n10000_0616_1134
#   Fidelity classica VAE vs esatta : 0.9888   <- MODELLO
#   Fidelity classica training vs esatta : 0.9961   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9642861376382376), np.float64(0.9513511015521965), np.float64(0.9678626256792825), np.float64(0.9767958264126101), np.float64(0.985054958249637), np.float64(0.9887893479263868)], 'Fc_train': [np.float64(0.8067273002400259), np.float64(0.8610482256997298), np.float64(0.9401718689623791), np.float64(0.974054221579064), np.float64(0.9917296439759965), np.float64(0.9960839436316434)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_6/vae_training_q4_n300_0616_1134
#   Fidelity classica VAE vs esatta : 0.9531   <- MODELLO
#   Fidelity classica training vs esatta : 0.8028   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_6/vae_training_q4_n500_0616_1134
#   Fidelity classica VAE vs esatta : 0.9606   <- MODELLO
#   Fidelity classica training vs esatta : 0.8773   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_6/vae_training_q4_n1000_0616_1134
#   Fidelity classica VAE vs esatta : 0.9653   <- MODELLO
#   Fidelity classica training vs esatta : 0.9357   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_6/vae_training_q4_n2000_0616_1134
#   Fidelity classica VAE vs esatta : 0.9676   <- MODELLO
#   Fidelity classica training vs esatta : 0.9685   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_6/vae_training_q4_n5000_0616_1134
#   Fidelity classica VAE vs esatta : 0.9834   <- MODELLO
#   Fidelity classica training vs esatta : 0.9898   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_6/vae_training_q4_n10000_0616_1135
#   Fidelity classica VAE vs esatta : 0.9871   <- MODELLO
#   Fidelity classica training vs esatta : 0.9951   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9531422795471302), np.float64(0.9606254709142229), np.float64(0.9652542597575471), np.float64(0.9675807627730129), np.float64(0.9833514258581674), np.float64(0.9870893838516626)], 'Fc_train': [np.float64(0.8028002400833338), np.float64(0.877289608897222), np.float64(0.9356924409681796), np.float64(0.9685275301842234), np.float64(0.9897506788907208), np.float64(0.9951444345781644)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_7/vae_training_q4_n300_0616_1135
#   Fidelity classica VAE vs esatta : 0.9556   <- MODELLO
#   Fidelity classica training vs esatta : 0.8035   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_7/vae_training_q4_n500_0616_1135
#   Fidelity classica VAE vs esatta : 0.9747   <- MODELLO
#   Fidelity classica training vs esatta : 0.8728   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_7/vae_training_q4_n1000_0616_1135
#   Fidelity classica VAE vs esatta : 0.9640   <- MODELLO
#   Fidelity classica training vs esatta : 0.9410   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_7/vae_training_q4_n2000_0616_1135
#   Fidelity classica VAE vs esatta : 0.9770   <- MODELLO
#   Fidelity classica training vs esatta : 0.9723   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_7/vae_training_q4_n5000_0616_1135
#   Fidelity classica VAE vs esatta : 0.9868   <- MODELLO
#   Fidelity classica training vs esatta : 0.9918   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_7/vae_training_q4_n10000_0616_1136
#   Fidelity classica VAE vs esatta : 0.9869   <- MODELLO
#   Fidelity classica training vs esatta : 0.9963   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9555567264509376), np.float64(0.9747215238194565), np.float64(0.9639648284600391), np.float64(0.9770202946834576), np.float64(0.9868292782063537), np.float64(0.986875625437954)], 'Fc_train': [np.float64(0.8035321092917573), np.float64(0.8728201175706883), np.float64(0.9410012891791326), np.float64(0.9723438255680715), np.float64(0.9918374573341079), np.float64(0.9962907182439995)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_8/vae_training_q4_n300_0616_1136
#   Fidelity classica VAE vs esatta : 0.9467   <- MODELLO
#   Fidelity classica training vs esatta : 0.8007   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_8/vae_training_q4_n500_0616_1136
#   Fidelity classica VAE vs esatta : 0.9589   <- MODELLO
#   Fidelity classica training vs esatta : 0.8748   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_8/vae_training_q4_n1000_0616_1136
#   Fidelity classica VAE vs esatta : 0.9591   <- MODELLO
#   Fidelity classica training vs esatta : 0.9494   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_8/vae_training_q4_n2000_0616_1136
#   Fidelity classica VAE vs esatta : 0.9805   <- MODELLO
#   Fidelity classica training vs esatta : 0.9755   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_8/vae_training_q4_n5000_0616_1136
#   Fidelity classica VAE vs esatta : 0.9871   <- MODELLO
#   Fidelity classica training vs esatta : 0.9911   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_8/vae_training_q4_n10000_0616_1137
#   Fidelity classica VAE vs esatta : 0.9867   <- MODELLO
#   Fidelity classica training vs esatta : 0.9960   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9467074878121486), np.float64(0.9589406693404202), np.float64(0.959140910932123), np.float64(0.9805405410705507), np.float64(0.9871082958851239), np.float64(0.9866674414893117)], 'Fc_train': [np.float64(0.8007004701373044), np.float64(0.8747612291917205), np.float64(0.9494376376346334), np.float64(0.9754637537293389), np.float64(0.9910809463015565), np.float64(0.9959646808096569)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_9/vae_training_q4_n300_0616_1137
#   Fidelity classica VAE vs esatta : 0.9567   <- MODELLO
#   Fidelity classica training vs esatta : 0.8282   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_9/vae_training_q4_n500_0616_1137
#   Fidelity classica VAE vs esatta : 0.9585   <- MODELLO
#   Fidelity classica training vs esatta : 0.8786   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_9/vae_training_q4_n1000_0616_1137
#   Fidelity classica VAE vs esatta : 0.9664   <- MODELLO
#   Fidelity classica training vs esatta : 0.9379   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_9/vae_training_q4_n2000_0616_1137
#   Fidelity classica VAE vs esatta : 0.9816   <- MODELLO
#   Fidelity classica training vs esatta : 0.9723   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_9/vae_training_q4_n5000_0616_1137
#   Fidelity classica VAE vs esatta : 0.9858   <- MODELLO
#   Fidelity classica training vs esatta : 0.9911   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_9/vae_training_q4_n10000_0616_1138
#   Fidelity classica VAE vs esatta : 0.9901   <- MODELLO
#   Fidelity classica training vs esatta : 0.9961   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.95668717752164), np.float64(0.9585210748556725), np.float64(0.966424861431718), np.float64(0.9816055014002062), np.float64(0.985829147192245), np.float64(0.990109914195256)], 'Fc_train': [np.float64(0.8281759775591362), np.float64(0.878603918958537), np.float64(0.9379052906900361), np.float64(0.9722605685155357), np.float64(0.9910778396497134), np.float64(0.9960844081652964)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_10/vae_training_q4_n300_0616_1138
#   Fidelity classica VAE vs esatta : 0.9489   <- MODELLO
#   Fidelity classica training vs esatta : 0.7989   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_10/vae_training_q4_n500_0616_1138
#   Fidelity classica VAE vs esatta : 0.9720   <- MODELLO
#   Fidelity classica training vs esatta : 0.8839   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_10/vae_training_q4_n1000_0616_1138
#   Fidelity classica VAE vs esatta : 0.9617   <- MODELLO
#   Fidelity classica training vs esatta : 0.9425   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_10/vae_training_q4_n2000_0616_1138
#   Fidelity classica VAE vs esatta : 0.9793   <- MODELLO
#   Fidelity classica training vs esatta : 0.9734   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_10/vae_training_q4_n5000_0616_1138
#   Fidelity classica VAE vs esatta : 0.9825   <- MODELLO
#   Fidelity classica training vs esatta : 0.9930   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_10/vae_training_q4_n10000_0616_1138
#   Fidelity classica VAE vs esatta : 0.9869   <- MODELLO
#   Fidelity classica training vs esatta : 0.9962   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9488733872941537), np.float64(0.9719865289515928), np.float64(0.961724098158895), np.float64(0.9793077844089018), np.float64(0.9824808378156992), np.float64(0.986901002973083)], 'Fc_train': [np.float64(0.7988557777826703), np.float64(0.8839158958585498), np.float64(0.9425368749154186), np.float64(0.9733637431744913), np.float64(0.9930363591995733), np.float64(0.996188890544568)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_11/vae_training_q4_n300_0616_1138
#   Fidelity classica VAE vs esatta : 0.9597   <- MODELLO
#   Fidelity classica training vs esatta : 0.8210   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_11/vae_training_q4_n500_0616_1138
#   Fidelity classica VAE vs esatta : 0.9545   <- MODELLO
#   Fidelity classica training vs esatta : 0.8886   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_11/vae_training_q4_n1000_0616_1139
#   Fidelity classica VAE vs esatta : 0.9648   <- MODELLO
#   Fidelity classica training vs esatta : 0.9398   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_11/vae_training_q4_n2000_0616_1139
#   Fidelity classica VAE vs esatta : 0.9665   <- MODELLO
#   Fidelity classica training vs esatta : 0.9719   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_11/vae_training_q4_n5000_0616_1139
#   Fidelity classica VAE vs esatta : 0.9797   <- MODELLO
#   Fidelity classica training vs esatta : 0.9914   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_11/vae_training_q4_n10000_0616_1139
#   Fidelity classica VAE vs esatta : 0.9879   <- MODELLO
#   Fidelity classica training vs esatta : 0.9952   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9596831800141549), np.float64(0.9545420042386457), np.float64(0.9648158981444965), np.float64(0.9664749834216895), np.float64(0.9797025146442118), np.float64(0.9879035688471607)], 'Fc_train': [np.float64(0.8210359340563835), np.float64(0.8885969263863008), np.float64(0.9398452838533053), np.float64(0.9718588276087552), np.float64(0.9914478401118731), np.float64(0.9952315275732476)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_12/vae_training_q4_n300_0616_1139
#   Fidelity classica VAE vs esatta : 0.9484   <- MODELLO
#   Fidelity classica training vs esatta : 0.8003   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_12/vae_training_q4_n500_0616_1139
#   Fidelity classica VAE vs esatta : 0.9600   <- MODELLO
#   Fidelity classica training vs esatta : 0.8918   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_12/vae_training_q4_n1000_0616_1139
#   Fidelity classica VAE vs esatta : 0.9717   <- MODELLO
#   Fidelity classica training vs esatta : 0.9419   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_12/vae_training_q4_n2000_0616_1139
#   Fidelity classica VAE vs esatta : 0.9786   <- MODELLO
#   Fidelity classica training vs esatta : 0.9746   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_12/vae_training_q4_n5000_0616_1140
#   Fidelity classica VAE vs esatta : 0.9871   <- MODELLO
#   Fidelity classica training vs esatta : 0.9911   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_12/vae_training_q4_n10000_0616_1140
#   Fidelity classica VAE vs esatta : 0.9858   <- MODELLO
#   Fidelity classica training vs esatta : 0.9960   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9484361323202104), np.float64(0.9600064426788099), np.float64(0.9717264227920446), np.float64(0.9785813068621877), np.float64(0.9871088910408464), np.float64(0.9858381608732439)], 'Fc_train': [np.float64(0.8003246687166518), np.float64(0.8917715526157477), np.float64(0.9418545119498847), np.float64(0.9746284842866407), np.float64(0.9910975803267923), np.float64(0.9959678733646486)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_13/vae_training_q4_n300_0616_1140
#   Fidelity classica VAE vs esatta : 0.9497   <- MODELLO
#   Fidelity classica training vs esatta : 0.7986   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_13/vae_training_q4_n500_0616_1140
#   Fidelity classica VAE vs esatta : 0.9543   <- MODELLO
#   Fidelity classica training vs esatta : 0.8848   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_13/vae_training_q4_n1000_0616_1140
#   Fidelity classica VAE vs esatta : 0.9771   <- MODELLO
#   Fidelity classica training vs esatta : 0.9359   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_13/vae_training_q4_n2000_0616_1140
#   Fidelity classica VAE vs esatta : 0.9778   <- MODELLO
#   Fidelity classica training vs esatta : 0.9712   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_13/vae_training_q4_n5000_0616_1140
#   Fidelity classica VAE vs esatta : 0.9817   <- MODELLO
#   Fidelity classica training vs esatta : 0.9915   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_13/vae_training_q4_n10000_0616_1141
#   Fidelity classica VAE vs esatta : 0.9863   <- MODELLO
#   Fidelity classica training vs esatta : 0.9959   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9496847333798671), np.float64(0.9543225160301623), np.float64(0.9771185217617292), np.float64(0.97776219104948), np.float64(0.9816595865309373), np.float64(0.9862712293508312)], 'Fc_train': [np.float64(0.7985683930530977), np.float64(0.8847528720433784), np.float64(0.9359476515053018), np.float64(0.9712216994716442), np.float64(0.9915032852014578), np.float64(0.9958630618868062)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_14/vae_training_q4_n300_0616_1141
#   Fidelity classica VAE vs esatta : 0.9504   <- MODELLO
#   Fidelity classica training vs esatta : 0.7890   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_14/vae_training_q4_n500_0616_1141
#   Fidelity classica VAE vs esatta : 0.9644   <- MODELLO
#   Fidelity classica training vs esatta : 0.8738   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_14/vae_training_q4_n1000_0616_1141
#   Fidelity classica VAE vs esatta : 0.9735   <- MODELLO
#   Fidelity classica training vs esatta : 0.9321   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_14/vae_training_q4_n2000_0616_1141
#   Fidelity classica VAE vs esatta : 0.9804   <- MODELLO
#   Fidelity classica training vs esatta : 0.9740   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_14/vae_training_q4_n5000_0616_1142
#   Fidelity classica VAE vs esatta : 0.9854   <- MODELLO
#   Fidelity classica training vs esatta : 0.9909   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_14/vae_training_q4_n10000_0616_1142
#   Fidelity classica VAE vs esatta : 0.9889   <- MODELLO
#   Fidelity classica training vs esatta : 0.9963   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9504417274206332), np.float64(0.9644198980408891), np.float64(0.9735405449492394), np.float64(0.980442195102977), np.float64(0.9853619087338634), np.float64(0.9888513733931931)], 'Fc_train': [np.float64(0.7890011392919273), np.float64(0.8737867512709075), np.float64(0.932132134033857), np.float64(0.9740232226840572), np.float64(0.9909332736841086), np.float64(0.9963169576077815)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_15/vae_training_q4_n300_0616_1142
#   Fidelity classica VAE vs esatta : 0.9567   <- MODELLO
#   Fidelity classica training vs esatta : 0.8194   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_15/vae_training_q4_n500_0616_1142
#   Fidelity classica VAE vs esatta : 0.9609   <- MODELLO
#   Fidelity classica training vs esatta : 0.8757   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_15/vae_training_q4_n1000_0616_1142
#   Fidelity classica VAE vs esatta : 0.9634   <- MODELLO
#   Fidelity classica training vs esatta : 0.9417   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_15/vae_training_q4_n2000_0616_1142
#   Fidelity classica VAE vs esatta : 0.9697   <- MODELLO
#   Fidelity classica training vs esatta : 0.9708   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_15/vae_training_q4_n5000_0616_1142
#   Fidelity classica VAE vs esatta : 0.9838   <- MODELLO
#   Fidelity classica training vs esatta : 0.9918   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_15/vae_training_q4_n10000_0616_1143
#   Fidelity classica VAE vs esatta : 0.9877   <- MODELLO
#   Fidelity classica training vs esatta : 0.9957   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9566579485060551), np.float64(0.9609088915801253), np.float64(0.963359254226675), np.float64(0.9697157657884924), np.float64(0.9838014636774742), np.float64(0.9877150487474233)], 'Fc_train': [np.float64(0.8194456845306232), np.float64(0.8756553087303113), np.float64(0.941665661042761), np.float64(0.9707641197950797), np.float64(0.9917839618575384), np.float64(0.9956539979751339)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_16/vae_training_q4_n300_0616_1143
#   Fidelity classica VAE vs esatta : 0.9594   <- MODELLO
#   Fidelity classica training vs esatta : 0.8023   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_16/vae_training_q4_n500_0616_1143
#   Fidelity classica VAE vs esatta : 0.9595   <- MODELLO
#   Fidelity classica training vs esatta : 0.8799   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_16/vae_training_q4_n1000_0616_1143
#   Fidelity classica VAE vs esatta : 0.9665   <- MODELLO
#   Fidelity classica training vs esatta : 0.9389   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_16/vae_training_q4_n2000_0616_1143
#   Fidelity classica VAE vs esatta : 0.9643   <- MODELLO
#   Fidelity classica training vs esatta : 0.9794   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_16/vae_training_q4_n5000_0616_1143
#   Fidelity classica VAE vs esatta : 0.9851   <- MODELLO
#   Fidelity classica training vs esatta : 0.9901   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_16/vae_training_q4_n10000_0616_1143
#   Fidelity classica VAE vs esatta : 0.9881   <- MODELLO
#   Fidelity classica training vs esatta : 0.9956   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9593605043378279), np.float64(0.9595298153175491), np.float64(0.9665075382535301), np.float64(0.9643249973452364), np.float64(0.985080907703767), np.float64(0.9880534781536502)], 'Fc_train': [np.float64(0.80233614517814), np.float64(0.8798665151756668), np.float64(0.9388736504892682), np.float64(0.9794061984295294), np.float64(0.9901341383848689), np.float64(0.9956385830905401)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_17/vae_training_q4_n300_0616_1144
#   Fidelity classica VAE vs esatta : 0.9457   <- MODELLO
#   Fidelity classica training vs esatta : 0.7913   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_17/vae_training_q4_n500_0616_1144
#   Fidelity classica VAE vs esatta : 0.9715   <- MODELLO
#   Fidelity classica training vs esatta : 0.8802   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_17/vae_training_q4_n1000_0616_1144
#   Fidelity classica VAE vs esatta : 0.9742   <- MODELLO
#   Fidelity classica training vs esatta : 0.9351   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_17/vae_training_q4_n2000_0616_1144
#   Fidelity classica VAE vs esatta : 0.9720   <- MODELLO
#   Fidelity classica training vs esatta : 0.9769   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_17/vae_training_q4_n5000_0616_1144
#   Fidelity classica VAE vs esatta : 0.9750   <- MODELLO
#   Fidelity classica training vs esatta : 0.9915   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_17/vae_training_q4_n10000_0616_1144
#   Fidelity classica VAE vs esatta : 0.9875   <- MODELLO
#   Fidelity classica training vs esatta : 0.9957   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9456594911100911), np.float64(0.971469736601085), np.float64(0.9742260164355393), np.float64(0.9719668603112416), np.float64(0.9750008445117798), np.float64(0.9875254398833565)], 'Fc_train': [np.float64(0.7913088540927538), np.float64(0.8802114501192174), np.float64(0.935109425364907), np.float64(0.9769094115034468), np.float64(0.9914930496269575), np.float64(0.9957281540170918)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_18/vae_training_q4_n300_0616_1144
#   Fidelity classica VAE vs esatta : 0.9514   <- MODELLO
#   Fidelity classica training vs esatta : 0.8064   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_18/vae_training_q4_n500_0616_1144
#   Fidelity classica VAE vs esatta : 0.9526   <- MODELLO
#   Fidelity classica training vs esatta : 0.8815   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_18/vae_training_q4_n1000_0616_1145
#   Fidelity classica VAE vs esatta : 0.9622   <- MODELLO
#   Fidelity classica training vs esatta : 0.9382   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_18/vae_training_q4_n2000_0616_1145
#   Fidelity classica VAE vs esatta : 0.9753   <- MODELLO
#   Fidelity classica training vs esatta : 0.9777   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_18/vae_training_q4_n5000_0616_1145
#   Fidelity classica VAE vs esatta : 0.9784   <- MODELLO
#   Fidelity classica training vs esatta : 0.9915   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_18/vae_training_q4_n10000_0616_1145
#   Fidelity classica VAE vs esatta : 0.9880   <- MODELLO
#   Fidelity classica training vs esatta : 0.9961   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.951365711060373), np.float64(0.9526171653202541), np.float64(0.9622221646882156), np.float64(0.9752618495219076), np.float64(0.9784102447048125), np.float64(0.9880465652650999)], 'Fc_train': [np.float64(0.8063990589564135), np.float64(0.8815384339396908), np.float64(0.9382061033587793), np.float64(0.9776558628958592), np.float64(0.9914912048367851), np.float64(0.9961496595209217)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_19/vae_training_q4_n300_0616_1145
#   Fidelity classica VAE vs esatta : 0.9517   <- MODELLO
#   Fidelity classica training vs esatta : 0.8031   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_19/vae_training_q4_n500_0616_1145
#   Fidelity classica VAE vs esatta : 0.9632   <- MODELLO
#   Fidelity classica training vs esatta : 0.8979   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_19/vae_training_q4_n1000_0616_1145
#   Fidelity classica VAE vs esatta : 0.9602   <- MODELLO
#   Fidelity classica training vs esatta : 0.9345   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_19/vae_training_q4_n2000_0616_1145
#   Fidelity classica VAE vs esatta : 0.9775   <- MODELLO
#   Fidelity classica training vs esatta : 0.9755   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_19/vae_training_q4_n5000_0616_1146
#   Fidelity classica VAE vs esatta : 0.9814   <- MODELLO
#   Fidelity classica training vs esatta : 0.9918   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_19/vae_training_q4_n10000_0616_1146
#   Fidelity classica VAE vs esatta : 0.9847   <- MODELLO
#   Fidelity classica training vs esatta : 0.9963   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9517085031788065), np.float64(0.9632087446418811), np.float64(0.9601733894192341), np.float64(0.9775012908559796), np.float64(0.9813970283802885), np.float64(0.9846582765965683)], 'Fc_train': [np.float64(0.8030616630784253), np.float64(0.8978778161611949), np.float64(0.9345032820352822), np.float64(0.975502812318322), np.float64(0.991813217193484), np.float64(0.9962788589463573)]}
#
# === N_QUBITS=4   N_SAMPLES=300 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_20/vae_training_q4_n300_0616_1146
#   Fidelity classica VAE vs esatta : 0.9445   <- MODELLO
#   Fidelity classica training vs esatta : 0.7811   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=500 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_20/vae_training_q4_n500_0616_1146
#   Fidelity classica VAE vs esatta : 0.9592   <- MODELLO
#   Fidelity classica training vs esatta : 0.8912   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=1000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_20/vae_training_q4_n1000_0616_1146
#   Fidelity classica VAE vs esatta : 0.9661   <- MODELLO
#   Fidelity classica training vs esatta : 0.9401   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=2000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_20/vae_training_q4_n2000_0616_1146
#   Fidelity classica VAE vs esatta : 0.9830   <- MODELLO
#   Fidelity classica training vs esatta : 0.9722   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=5000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_20/vae_training_q4_n5000_0616_1146
#   Fidelity classica VAE vs esatta : 0.9876   <- MODELLO
#   Fidelity classica training vs esatta : 0.9901   <- TETTO
#
# === N_QUBITS=4   N_SAMPLES=10000 ===
# All saved in: /Users/riccardoruggeri/project-sda/statistical-qst-vae/results/vae_analysis/run_20/vae_training_q4_n10000_0616_1147
#   Fidelity classica VAE vs esatta : 0.9875   <- MODELLO
#   Fidelity classica training vs esatta : 0.9958   <- TETTO
#
# RESULTS: {'n_samples': [300, 500, 1000, 2000, 5000, 10000], 'Fc': [np.float64(0.9444739399307458), np.float64(0.9592340715687083), np.float64(0.9661283256120565), np.float64(0.982992102910439), np.float64(0.9876109453809363), np.float64(0.9874557615902891)], 'Fc_train': [np.float64(0.7810874649358618), np.float64(0.8912205202397966), np.float64(0.9401128448242817), np.float64(0.972234540037352), np.float64(0.9901418613648092), np.float64(0.9957936283678815)]}

# %%
# Carica i risultati di run_1 ... run_N, calcola media e std della fidelity
# classica su tutte le run e plotta F_c vs N_SAMPLES con barre d'errore,
# una curva per ogni numero di qubit.
N_RUNS = 20
P_unif = {o: 1.0 / len(outcomes) for o in outcomes}

# Concatena i CSV di tutte le run in un unico DataFrame
runs = []
for i in range(1, N_RUNS + 1):
    csv_path = RESULTS_ROOT / f"run_{i}" / "4q_vae_advantage.csv"
    df_i = pd.read_csv(csv_path)
    df_i["run"] = i
    runs.append(df_i)
all_runs = pd.concat(runs, ignore_index=True)

# Media e deviazione standard di Fc (e Fc_train) sulle run, per ogni (n_qubits, n_samples)
stats = (
    all_runs
    .groupby(["n_samples"])
    .agg(Fc_mean=("Fc", "mean"), Fc_std=("Fc", "std"),
         Fc_train_mean=("Fc_train", "mean"), Fc_train_std=("Fc_train", "std"))
    .reset_index()
)

# Plot: fidelity media vs N_SAMPLES con barre d'errore (std), una curva per numero di qubit
plt.figure(figsize=(8, 5))

sub = stats.sort_values("n_samples")
plt.errorbar(sub["n_samples"], sub["Fc_mean"], yerr=sub["Fc_std"],
                fmt='-o', color='orange', capsize=4, label=f'4 qubit (VAE)')
plt.errorbar(sub["n_samples"], sub["Fc_train_mean"], yerr=sub["Fc_train_std"],
                fmt='--s', color='blue', capsize=4, label=f'4 qubit (train)')

# Fill between: train classical fidelity and VAE classical fidelity
# Orange fill when VAE fidelity is higher than train fidelity, blue fill otherwise
plt.fill_between(sub["n_samples"], sub["Fc_mean"], sub["Fc_train_mean"],
                 where=sub["Fc_mean"] >= sub["Fc_train_mean"],
                 interpolate=True, color='orange', alpha=0.2, label='VAE > Train')
plt.fill_between(sub["n_samples"], sub["Fc_mean"], sub["Fc_train_mean"],
                 where=sub["Fc_mean"] < sub["Fc_train_mean"],
                 interpolate=True, color='blue', alpha=0.2, label='Train > VAE')


plt.axhline(y=classical_fidelity(P_unif, P_exact), color='black', linestyle=':', label='Uniform distribution')
plt.xscale('log')
plt.xlabel('Training samples')
plt.ylabel('Classical Fidelity')
plt.title(f'Classical Fidelity vs Training Samples (mean ± std over {N_RUNS} runs, 4 qubits)')
plt.grid(True, which='both', ls=':', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.savefig(PROJECT_ROOT / "results" / "classical_fidelity_vs_samples.svg")

stats
# Out:
#    n_samples   Fc_mean    Fc_std  Fc_train_mean  Fc_train_std
# 0        300  0.952682  0.005225       0.804984      0.014231
# 1        500  0.960685  0.006929       0.881670      0.008555
# 2       1000  0.965931  0.004856       0.940766      0.005345
# 3       2000  0.975116  0.005598       0.973759      0.002745
# 4       5000  0.983295  0.003860       0.991311      0.000778
# 5      10000  0.987708  0.001449       0.995908      0.000364

# %%
from povm_sampling import onehot_to_samples

N_SAMPLES = [5000, 10000, 20000, 50000]
N_QUBITS = [4, 6, 8]

# geometria (latent_dim, hidden, N_GEN) per numero di qubit
CFG = {
    #3: dict(latent_dim=16,  hidden=96,  batch_size=100, N_GEN=20000),
    4: dict(latent_dim=32,  hidden=128,  batch_size=200, N_GEN=100000),
    #5: dict(latent_dim=64,  hidden=224,  batch_size=500, N_GEN=4**5 * 500),
    6: dict(latent_dim=256, hidden=1280, batch_size=600, N_GEN=4**6 * 500),
    #7: dict(latent_dim=512, hidden=1504, batch_size=800, N_GEN=4**7 * 500),
    8: dict(latent_dim=512, hidden=2560, batch_size=1000, N_GEN=4**8 * 500),
}
# accumulo i risultati per il plot finale: una curva per ogni numero di qubit
results = {q: {"n_samples": [], "Fc": [], "Fc_train": []} for q in N_QUBITS}

for q in N_QUBITS:
    # GHZ esatto + distribuzione POVM vera
    qc = create_ghz_state(q)
    rho = DensityMatrix(qc)
    P_exact = povm_probability_efficient(rho.data, q)
    outcomes = list(P_exact.keys())            # ricalcolato per ogni q (era un bug: restava a 3 qubit)

    for n in N_SAMPLES:
        print(f"\n=== N_QUBITS={q}   N_SAMPLES={n} ===")
        n_samples = n

        seed = np.random.seed(42 + n + q)  # seed diverso per ogni combinazione di n e q, ma fisso tra le run
        # campiona la distribuzione e prepara i dati
        sample = sample_povm(P_exact, n_samples=n_samples, seed=seed)
        onehot_sample = samples_to_onehot(sample, q)
        X_train, X_test = train_test_split(onehot_sample, test_size=0.2, random_state=42)

        cfg = CFG[q]
        latent_dim, hidden, batch_size, N_GEN = cfg["latent_dim"], cfg["hidden"], cfg["batch_size"], cfg["N_GEN"]

        vae = VAE(n_qubits=q, latent_dim=latent_dim, hidden=hidden)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3))
        vae.build(input_shape=(None, 4 * q))
        model = vae

        WARMUP = 40   # epoche di warm-up della KL (0 -> beta_max)
        callbacks = [
            KLWarmup(beta_max=0.85, warmup_epochs=WARMUP),
            EarlyStopping(monitor='reconstruction_loss', mode='min',
                            patience=40, restore_best_weights=True, start_from_epoch=WARMUP),
        ]

        history = model.fit(
            X_train, X_train,
            epochs=500,
            batch_size=batch_size,
            validation_data=(X_test, X_test),
            callbacks=callbacks,
            verbose=0,
        )

        # save results
        drive_path = RESULTS_ROOT / "run_{}".format(i+1)
        run_dir, checkpoint_path, history_path = set_up_training(experiment_id='vae_training_q{}_n{}'.format(q, n), drive_path = drive_path)
        model.save_weights(checkpoint_path)
        pd.DataFrame(history.history).to_csv(history_path, index=False)

        # campiona dal VAE e calcola le metriche vs la distribuzione esatta
        P_vae   = vae.predict_dist(n_samples=N_GEN, batch_size=50_000)
        P_train = samples_to_empirical_dist(onehot_to_samples(X_train, q), q)

        Fc        = classical_fidelity(P_vae,   P_exact)
        Fc_train  = classical_fidelity(P_train, P_exact)

        # Print with minimal informations
        print(f"  Classical Fidelity VAE vs exact: {Fc:.4f}   <- MODEL")
        print(f"  Classical Fidelity training vs exact: {Fc_train:.4f}   <- BASELINE")

        # salvo la fidelity classica per il plot al variare di N_SAMPLES e N_QUBITS
        # (atteso: cresce con n_samples, cala con n_qubits)
        results[q]["n_samples"].append(n)
        results[q]["Fc"].append(Fc)
        results[q]["Fc_train"].append(Fc_train)

    print("\nRESULTS:", results)

# Save results to a CSV file for later analysis and plotting
results_df = pd.DataFrame({
    "n_qubits": np.repeat(N_QUBITS, len(N_SAMPLES)),
    "n_samples": np.tile(N_SAMPLES, len(N_QUBITS)),
    "Fc": [results[q]["Fc"][i] for q in N_QUBITS for i in range(len(N_SAMPLES))],
    "Fc_train": [results[q]["Fc_train"][i] for q in N_QUBITS for i in range(len(N_SAMPLES))],
})

# Save the results to a CSV file for later analysis and plotting PROJECT_ROOT
results_df.to_csv(drive_path / "vae_scalability_results.csv", index=False)
# Out:
# === N_QUBITS=4   N_SAMPLES=5000 ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 49
#      45             EarlyStopping(monitor='reconstruction_loss', mode='min',
#      46                             patience=40, restore_best_weights=True, start_from_epoch=WARMUP),
#      47         ]
#      48
# ---> 49         history = model.fit(
#      50             X_train, X_train,
#      51             epochs=500,
#      52             batch_size=batch_size,
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/project-sda/statistical-qst-vae/sda-env/lib/python3.13/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
